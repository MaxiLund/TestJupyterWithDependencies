# %% [markdown]
# Weather Analysis for:

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
import sys
from IPython import display
from IPython.display import HTML

sys.path.append("""C:/Users/Maxi/Documents/Development/TestPostgres""")
from Main.Main import EnvironmentalAnalyzer
# %matplotlib inline

class Location:
    def __init(self):
        self.location = 2
    def printGraph(self):
        test =EnvironmentalAnalyzer()
        print("Location2",self.location)
        test.printGraph(self.location,1)
    def setLocation(self,i):
        print("i",i)
        self.location = i
        print("self.location",self.location)
loc = Location()       

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
locationWidget = widgets.Dropdown(
    options=['München','Nürnberg','Würzburg'],
    value='München',
    description='Location:',
    disabled=False,
)

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        if change['new']=="München":
            loc.setLocation(0)
        elif change['new']=="Nürnberg":
            loc.setLocation(1)
        elif change['new']=="Würzburg":
            loc.setLocation(2)
        print("Loc1", loc.location)
        loc.printGraph()
        display.clear_output(wait=True)

locationWidget.observe(on_change)

locationWidget
# Out:
# i 1
# self.location 1
# Loc1 1
# Location2 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29408)()
#
# pandas\src\datetime.pxd in datetime._string_to_dts (pandas\tslib.c:95676)()
#
# ValueError: Error parsing datetime string "None" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29833)()
#
# pandas\tslib.pyx in pandas.tslib.parse_datetime_string (pandas\tslib.c:35434)()
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#    1167     else:
# -> 1168         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1169
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#
# ValueError: Unknown string format
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     456                 for i,k in enumerate(data.get('buffer_keys', [])):
#     457                     sync_data[k] = msg['buffers'][i]
# --> 458                 self.set_state(sync_data) # handles all methods
#     459
#     460         # Handle a state request.
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     335                     from_json = self.trait_metadata(name, 'from_json',
#     336                                                     self._trait_from_json)
# --> 337                     self.set_trait(name, from_json(sync_data[name], self))
#     338
#     339     def send(self, content, buffers=None):
#
# C:\Users\Maxi\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1127                 for changes in cache.values():
#    1128                     for change in changes:
# -> 1129                         self.notify_change(change)
#    1130
#    1131     def _notify_trait(self, name, old_value, new_value):
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     396                 # Send new state to front-end
#     397                 self.send_state(key=name)
# --> 398         LoggingConfigurable.notify_change(self, change)
#     399
#     400     #-------------------------------------------------------------------------
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1172                 c = getattr(self, c.name)
#    1173
# -> 1174             c(change)
#    1175
#    1176     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-67-08696d08acba> in on_change(change)
#      15             loc.setLocation(2)
#      16         print("Loc1", loc.location)
# ---> 17         loc.printGraph()
#      18         display.clear_output(wait=True)
#      19
#
# <ipython-input-66-d9644375e105> in printGraph(self)
#      16         test =EnvironmentalAnalyzer()
#      17         print("Location2",self.location)
# ---> 18         test.printGraph(self.location,1)
#      19     def setLocation(self,i):
#      20         print("i",i)
#
# C:/Users/Maxi/Documents/Development/TestPostgres\Main\Main.py in printGraph(self, location, parameter)
#      95         for minDate, in minimumDate:
#      96             for cDates, in countDates:
# ---> 97                 ts = pandas.Series(rows, index=pandas.date_range(start=str(minDate), periods=cDates))
#      98
#      99                 ts.plot()
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    2022     return DatetimeIndex(start=start, end=end, periods=periods,
#    2023                          freq=freq, tz=tz, normalize=normalize, name=name,
# -> 2024                          closed=closed, **kwargs)
#    2025
#    2026
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\util\decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     299             return cls._generate(start, end, periods, name, freq,
#     300                                  tz=tz, normalize=normalize, closed=closed,
# --> 301                                  ambiguous=ambiguous)
#     302
#     303         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in _generate(cls, start, end, periods, name, offset, tz, normalize, ambiguous, closed)
#     401
#     402         if start is not None:
# --> 403             start = Timestamp(start)
#     404
#     405         if end is not None:
#
# pandas\tslib.pyx in pandas.tslib.Timestamp.__new__ (pandas\tslib.c:10447)()
#
# pandas\tslib.pyx in pandas.tslib.convert_to_tsobject (pandas\tslib.c:27555)()
#
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29886)()
#
# ValueError: could not convert string to Timestamp
# i 0
# self.location 0
# Loc1 0
# Location2 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29408)()
#
# pandas\src\datetime.pxd in datetime._string_to_dts (pandas\tslib.c:95676)()
#
# ValueError: Error parsing datetime string "None" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29833)()
#
# pandas\tslib.pyx in pandas.tslib.parse_datetime_string (pandas\tslib.c:35434)()
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#    1167     else:
# -> 1168         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1169
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     558         if res is None:
# --> 559             raise ValueError("Unknown string format")
#     560
#
# ValueError: Unknown string format
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     456                 for i,k in enumerate(data.get('buffer_keys', [])):
#     457                     sync_data[k] = msg['buffers'][i]
# --> 458                 self.set_state(sync_data) # handles all methods
#     459
#     460         # Handle a state request.
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     335                     from_json = self.trait_metadata(name, 'from_json',
#     336                                                     self._trait_from_json)
# --> 337                     self.set_trait(name, from_json(sync_data[name], self))
#     338
#     339     def send(self, content, buffers=None):
#
# C:\Users\Maxi\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      87         if type is None:
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#      91                 return
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1127                 for changes in cache.values():
#    1128                     for change in changes:
# -> 1129                         self.notify_change(change)
#    1130
#    1131     def _notify_trait(self, name, old_value, new_value):
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     396                 # Send new state to front-end
#     397                 self.send_state(key=name)
# --> 398         LoggingConfigurable.notify_change(self, change)
#     399
#     400     #-------------------------------------------------------------------------
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1172                 c = getattr(self, c.name)
#    1173
# -> 1174             c(change)
#    1175
#    1176     def _add_notifiers(self, handler, name, type):
#
# <ipython-input-67-08696d08acba> in on_change(change)
#      15             loc.setLocation(2)
#      16         print("Loc1", loc.location)
# ---> 17         loc.printGraph()
#      18         display.clear_output(wait=True)
#      19
#
# <ipython-input-66-d9644375e105> in printGraph(self)
#      16         test =EnvironmentalAnalyzer()
#      17         print("Location2",self.location)
# ---> 18         test.printGraph(self.location,1)
#      19     def setLocation(self,i):
#      20         print("i",i)
#
# C:/Users/Maxi/Documents/Development/TestPostgres\Main\Main.py in printGraph(self, location, parameter)
#      95         for minDate, in minimumDate:
#      96             for cDates, in countDates:
# ---> 97                 ts = pandas.Series(rows, index=pandas.date_range(start=str(minDate), periods=cDates))
#      98
#      99                 ts.plot()
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    2022     return DatetimeIndex(start=start, end=end, periods=periods,
#    2023                          freq=freq, tz=tz, normalize=normalize, name=name,
# -> 2024                          closed=closed, **kwargs)
#    2025
#    2026
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\util\decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in __new__(cls, data, freq, start, end, periods, copy, name, tz, verify_integrity, normalize, closed, ambiguous, dtype, **kwargs)
#     299             return cls._generate(start, end, periods, name, freq,
#     300                                  tz=tz, normalize=normalize, closed=closed,
# --> 301                                  ambiguous=ambiguous)
#     302
#     303         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# C:\Users\Maxi\Anaconda3\lib\site-packages\pandas\tseries\index.py in _generate(cls, start, end, periods, name, offset, tz, normalize, ambiguous, closed)
#     401
#     402         if start is not None:
# --> 403             start = Timestamp(start)
#     404
#     405         if end is not None:
#
# pandas\tslib.pyx in pandas.tslib.Timestamp.__new__ (pandas\tslib.c:10447)()
#
# pandas\tslib.pyx in pandas.tslib.convert_to_tsobject (pandas\tslib.c:27555)()
#
# pandas\tslib.pyx in pandas.tslib.convert_str_to_tsobject (pandas\tslib.c:29886)()
#
# ValueError: could not convert string to Timestamp
